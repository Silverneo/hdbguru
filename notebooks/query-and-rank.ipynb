# %%
import datetime

# %%
import pandas as pd
import numpy as np
import requests

# %%
from sqlalchemy import create_engine

# %%
def onemap_search(placename):
    onemapSearchUrl = "https://developers.onemap.sg/commonapi/search?searchVal={}&returnGeom=Y&getAddrDetails=Y"
    res = requests.get(onemapSearchUrl.format(placename))
    if res.status_code != 200:
        return None
    try:
        res = res.json()
    except Exception as e:
        print(placename, e)
    if res['found'] == 0:
        return None
    return res['results'][0]

# %%
onemap_search('5 science park')
# Out:
# {'ADDRESS': '5 SCIENCE PARK DRIVE SINGAPORE 118265',
#  'BLK_NO': '5',
#  'BUILDING': 'NIL',
#  'LATITUDE': '1.29207905014866',
#  'LONGITUDE': '103.786710614115',
#  'LONGTITUDE': '103.786710614115',
#  'POSTAL': '118265',
#  'ROAD_NAME': 'SCIENCE PARK DRIVE',
#  'SEARCHVAL': '5 SCIENCE PARK DRIVE SINGAPORE 118265',
#  'X': '22812.9348640535',
#  'Y': '30497.1033341698'}

# %%
onemap_search('118265')
# Out:
# {'ADDRESS': '5 SCIENCE PARK DRIVE SINGAPORE 118265',
#  'BLK_NO': '5',
#  'BUILDING': 'NIL',
#  'LATITUDE': '1.29207905014866',
#  'LONGITUDE': '103.786710614115',
#  'LONGTITUDE': '103.786710614115',
#  'POSTAL': '118265',
#  'ROAD_NAME': 'SCIENCE PARK DRIVE',
#  'SEARCHVAL': '5 SCIENCE PARK DRIVE SINGAPORE 118265',
#  'X': '22812.9348640535',
#  'Y': '30497.1033341698'}

# %%
db_string = "postgres://hgadmin:pwd123456@127.0.0.1:5432/hdbguru"
db = create_engine(db_string)

# %% [markdown]
# ###### check tabels

# %%
all_tbl = pd.read_sql("select * from information_schema.tables where table_schema = 'api'", db)

# %%
all_tbl
# Out:
#    table_catalog table_schema                 table_name  table_type  \
# 0        hdbguru          api            tbl_school_info  BASE TABLE
# 1        hdbguru          api          tbl_hdb_addr_info  BASE TABLE
# 2        hdbguru          api          tbl_hdb_prop_info  BASE TABLE
# 3        hdbguru          api       tbl_hdb_resale_price  BASE TABLE
# 4        hdbguru          api         tbl_smkt_addr_info  BASE TABLE
# 5        hdbguru          api       tbl_hawker_addr_info  BASE TABLE
# 6        hdbguru          api      tbl_mrt_lrt_addr_info  BASE TABLE
# 7        hdbguru          api         tbl_mall_addr_info  BASE TABLE
# 8        hdbguru          api  tbl_stats_hdb_supermarket  BASE TABLE
# 9        hdbguru          api       tbl_stats_hdb_school  BASE TABLE
# 10       hdbguru          api       tbl_stats_hdb_hawker  BASE TABLE
# 11       hdbguru          api      tbl_stats_hdb_station  BASE TABLE
# 12       hdbguru          api         tbl_stats_hdb_mall  BASE TABLE
# ...

# %%
sql = """
    SELECT *
    FROM api.{}
    LIMIT 10
"""

# %%
tbl="vw_stats_hdb_surroundings"

# %%
df = pd.read_sql(sql.format(tbl), db)

# %%
df.head()
# Out:
#      hdb_id  hawker_cnt_1km_2km  hawker_cnt_500_1km  hawker_cnt_wth_500  \
# 0  86911a37                   6                   3                   2
# 1  5722e252                   4                   3                   1
# 2  8adc56ac                   1                   0                   0
# 3  e53c4395                   2                   1                   0
# 4  714aa4c4                   2                   0                   0
#
#    school_cnt_1km_2km  school_cnt_500_1km  school_cnt_wth_500  \
# 0                   4                   1                   1
# 1                   5                   3                   1
# 2                   2                   1                   1
# 3                  13                   2                   2
# 4                   6                   4                   2
#
#    station_cnt_1km_2km  station_cnt_500_1km  station_cnt_wth_500  \
# 0                    1                    1                    0
# ...

# %%
tbl="tbl_hdb_prop_info"

# %%
df = pd.read_sql(sql.format(tbl), db)

# %%
df.head()
# Out:
#               town block        street_name  max_floor_lvl  year_completed  \
# 0  KALLANG/WHAMPOA     1           BEACH RD             16            1970
# 1            BEDOK     1    BEDOK STH AVE 1             14            1975
# 2     CENTRAL AREA     1      CANTONMENT RD              2            2010
# 3            BEDOK     1       CHAI CHEE RD             15            1982
# 4        PASIR RIS     1  CHANGI VILLAGE RD              4            1975
#
#    residential  commercial  market_hawker  miscellaneous  multistorey_carpark  \
# 0            1           1              0              0                    0
# 1            1           0              0              1                    0
# 2            0           1              0              0                    0
# 3            1           0              0              0                    0
# 4            1           1              0              0                    0
#
# ...

# %%
tbl="tbl_hdb_resale_price"

# %%
df = pd.read_sql(sql.format(tbl), db)

# %%
df.tail()
# Out:
#         month     town block    street_name flat_type flat_model  \
# 5  2015-02-28  GEYLANG   126    ALJUNIED RD    5 ROOM   IMPROVED
# 6  2015-02-28  HOUGANG     6  HOUGANG AVE 3    3 ROOM   IMPROVED
# 7  2015-02-28   YISHUN   297   YISHUN ST 20    5 ROOM   IMPROVED
# 8  2015-02-28   YISHUN   758   YISHUN ST 72    5 ROOM   IMPROVED
# 9  2015-02-28   YISHUN   419  YISHUN AVE 11    5 ROOM    MODEL A
#
#    lease_commence_date  floor_area_sqm  resale_price  storey_range_from  \
# 5                 1983           121.0      555000.0                  4
# 6                 1975            59.0      250000.0                  4
# 7                 2000           112.0      470000.0                  1
# 8                 1986           121.0      488000.0                  7
# 9                 1993           133.0      490888.0                  7
#
#    storey_range_to    hdb_id  price_psf  price_psm
# 5                6  1f49532c  426.12198  4586.7770
# ...

# %%
555000/426
# Out:
# 1302.8169014084508

# %%
tbl='tbl_mall_addr_info'

# %%
df = pd.read_sql(sql.format(tbl), db)

# %%
df.head()
# Out:
#                              name block        street_name postal_code  \
# 0                          100 AM   100        TRAS STREET      079027
# 1                    313@SOMERSET   313       ORCHARD ROAD      238895
# 2                          APERIA    12     KALLANG AVENUE      339511
# 3  BALESTIER HILL SHOPPING CENTRE    1A       THOMSON ROAD      301001
# 4                      BUGIS CUBE   470  NORTH BRIDGE ROAD      188735
#
#                                              address  \
# 0            100 TRAS STREET 100 AM SINGAPORE 079027
# 1  313 ORCHARD ROAD UOB 313@SOMERSET SINGAPORE 23...
# 2  12 KALLANG AVENUE JOSIAH BABIES (APERIA) SINGA...
# 3  1A THOMSON ROAD BALESTIER HILL SHOPPING CENTRE...
# 4  470 NORTH BRIDGE ROAD BUGIS CUBE SINGAPORE 188735
#
#                          building  latitude   longitude          x          y  \
# 0                          100 AM  1.274588  103.843470  29129.855  28563.012
# ...

# %%
tbl='tbl_hawker_addr_info'

# %%
df = pd.read_sql(sql.format(tbl), db)

# %%
df.head()
# Out:
#                                                 name  latitude  longitude  \
# 0  Buffalo Road Blk 665 (Tekka Centre/Zhu Jiao Ma...  1.306206  103.85053
# 1  Bukit Merah Central Blk 163 (Bukit Merah Centr...  1.283693  103.81699
# 2  Bukit Merah Lane 1 Blk 120 (Alexandra Village ...  1.286298  103.80449
# 3               Queen Street Blk 270 (Albert Centre)  1.301001  103.85421
# 4  Toa Payoh Lorong 7 Blk 22 (Kim Keat Palm Marke...  1.335231  103.85703
#
#                                                 geom
# 0  0101000020E6100000000000206FF659400000002038E6...
# 1  0101000020E6100000000000A049F4594000000040018A...
# 2  0101000020E6100000000000C07CF3594000000000AD94...
# 3  0101000020E610000000000060ABF65940000000E0E6D0...
# 4  0101000020E6100000000000A0D9F65940000000A01B5D...

# %%
tbl='tbl_hdb_addr_info'

# %%
df = pd.read_sql(sql.format(tbl), db)

# %%
df.head()
# Out:
#               town block        street_name postal_code  \
# 0  KALLANG/WHAMPOA     1           BEACH RD      190001
# 1            BEDOK     1    BEDOK STH AVE 1      460001
# 2     CENTRAL AREA     1      CANTONMENT RD      080001
# 3            BEDOK     1       CHAI CHEE RD      461001
# 4        PASIR RIS     1  CHANGI VILLAGE RD      500001
#
#                                              address             building  \
# 0   1 BEACH ROAD BEACH ROAD GARDENS SINGAPORE 190001   BEACH ROAD GARDENS
# 1            1 BEDOK SOUTH AVENUE 1 SINGAPORE 460001                  NIL
# 2  1 CANTONMENT ROAD THE PINNACLE@DUXTON SINGAPOR...  THE PINNACLE@DUXTON
# 3  1 CHAI CHEE ROAD PING YI GARDENS SINGAPORE 461001      PING YI GARDENS
# 4             1 CHANGI VILLAGE ROAD SINGAPORE 500001                  NIL
#
#    latitude   longitude          x          y  \
# 0  1.303671  103.864480  31467.832  31778.895
# 1  1.320852  103.933720  39173.812  33678.855
# ...

# %% [markdown]
# ###### query top 20 nearest HDB blocks (for listing page)

# %%
topn_sql = """
SELECT *
FROM 
(
    SELECT 
        hdb_id,
        town,
        block,
        street_name,
        address,
        building,
        ST_DistanceSphere(
          ST_SetSRID(ST_Point({}, {}), 4326),
          geom
        ) as distance_to_target,
        postal_code,
        latitude,
        longitude
    FROM api.tbl_hdb_addr_info 
    ORDER BY distance_to_target
    LIMIT {}
) AS hdb_addr_tbl
INNER JOIN
(
    SELECT *
    FROM api.vw_stats_hdb_surroundings
) AS hdb_surround_tbl
ON hdb_addr_tbl.hdb_id = hdb_surround_tbl.hdb_id
INNER JOIN
(
    SELECT 
        hdb_id,
        CAST(AVG(price_psf) AS INT) AS avg_price_psf,
        lease_commence_date,
        flat_type,
        CAST(AVG(floor_area_sqm) AS INT) AS floor_area_sqm
    FROM api.tbl_hdb_resale_price
    WHERE month > date('{}-01-01')
    GROUP BY hdb_id,lease_commence_date, flat_type
) AS hdb_price_tbl
ON hdb_addr_tbl.hdb_id = hdb_price_tbl.hdb_id
ORDER BY hdb_addr_tbl.distance_to_target
"""

# %%
onemap_search('531008')
# Out:
# {'ADDRESS': '8 LORONG LEW LIAN SINGAPORE 531008',
#  'BLK_NO': '8',
#  'BUILDING': 'NIL',
#  'LATITUDE': '1.3489086885502',
#  'LONGITUDE': '103.876715676102',
#  'LONGTITUDE': '103.876715676102',
#  'POSTAL': '531008',
#  'ROAD_NAME': 'LORONG LEW LIAN',
#  'SEARCHVAL': '8 LORONG LEW LIAN SINGAPORE 531008',
#  'X': '32829.6134241363',
#  'Y': '36781.0283859018'}

# %%
r = onemap_search('531008')

# %%
query_lang = r['LONGITUDE']
query_lat = r['LATITUDE']
max_return = 20
cur_year = datetime.date.today().year

# %%
df = pd.read_sql(topn_sql.format(query_lang, query_lat, max_return, cur_year-10), db)

# %%
# drop duplicated columns
df = df.loc[:,~df.columns.duplicated()]

# %%
df['remain_lease'] = df['lease_commence_date'].apply(lambda x: 99-(cur_year-x))

# %%
df['floor_area_sqft'] = df['floor_area_sqm'] * 10.7639

# %%
df['avg_resale_price'] = df.apply(lambda row: row['avg_price_psf'] * row['floor_area_sqft'], axis=1)

# %%
df = df.drop_duplicates(subset=['hdb_id'])

# %%
# postcode, type, area (sqft), total price, lat, lang

# %%
df.iloc[0]
# Out:
# hdb_id                                           c3146109
# town                                            SERANGOON
# block                                                   8
# street_name                                  LOR LEW LIAN
# address                8 LORONG LEW LIAN SINGAPORE 531008
# building                                              NIL
# distance_to_target                               0.104274
# postal_code                                        531008
# latitude                                          1.34891
# longitude                                         103.877
# hawker_cnt_1km_2km                                      4
# hawker_cnt_500_1km                                      0
# hawker_cnt_wth_500                                      0
# school_cnt_1km_2km                                      5
# school_cnt_500_1km                                      3
# school_cnt_wth_500                                      0
# ...

# %%
df.shape
# Out:
# (19, 32)

# %% [markdown]
# ###### score computation

# %%
# user preference matrix (each with range 1-5 -> normalize all into 0-1, sum will be 1):
# - distance to work place
# - average resale price for past 10 years 
# - years of remaining lease 
# - transportation
# - shopping
# - eating
# - education

# %%
# factors affect score computation (each with score 1-5 -> to be multiplied by the user preference matrix then sum up):
# - distance to work place                
    # (5:<1000, 4:1001-5000, 3:5001-10000, 2:10001-15000, 1:>15001)
# - average resale price for past 10 years 
    # (5:<500 psft, 4:501-600 psft, 3:601-700 psft, 2: 701-800 psft, 1:>801 psft)
# - years of remaining lease              
    # (5:>90, 4:81-90, 3:71-80, 2:61-70, 1:<60)
# - #of nearby station                    
    # (5: more than 2 within 500m, 4: 1 within 500m, 3: more than 2 within 1000m, 
    #  2: 1 within 1000m, 1: more than 1 within 2000m, 0: no within 2000m)
# - #of nearby mall & market              
    # (5: more than 2 within 500m, 4: 1 within 500m, 3: more than 2 within 1000m, 
    #  2: 1 within 1000m, 1: more than 1 within 2000m, 0: no within 2000m)
# - #of nearby hawker                     
    # (5: more than 2 within 500m, 4: 1 within 500m, 3: more than 2 within 1000m, 
    #  2: 1 within 1000m, 1: more than 1 within 2000m, 0: no within 2000m)
# - #of nearby school                     
    # (5: more than 3 within 1000m, 4: 2 within 1000m, 3: 1 within 1000m, 
    #  2: more than 2 within 2000m, 1: 1 within 2000m, 0: no within 2000m)

# %%
# user_matrix = np.array([5, 5, 2, 5, 3, 5, 1])
user_matrix = np.array([5, 2.5, 2.5, 2.5, 2.5, 5, 2.5])

# %%
user_matrix_norm = user_matrix/sum(user_matrix)

# %%
user_matrix_norm
# Out:
# array([0.22222222, 0.11111111, 0.11111111, 0.11111111, 0.11111111,
#        0.22222222, 0.11111111])

# %%
sum(user_matrix_norm)
# Out:
# 1.0

# %%
def distance_score(dist):
    if dist <= 1000:
        return 5
    elif 1000 < dist <= 5000:
        return 4
    elif 5000 < dist <= 10000:
        return 3
    elif 10000 < dist <= 15000:
        return 2
    else:
        return 1
    
def price_score(price):
    if price <= 500:
        return 5
    elif 500 < price <= 600:
        return 4
    elif 600 < price <= 700:
        return 3
    elif 700 < price <= 800:
        return 2
    else:
        return 1

def lease_score(lease):
    if lease >= 90:
        return 5
    elif 80 <= lease < 90:
        return 4
    elif 70 <= lease < 80:
        return 3
    elif 60 <= lease < 70:
        return 2
    else:
        return 1
    
def surrounding_score(n_500, n_1000, n_2000):
    
    if n_500 >= 2:
        score = 5 
    elif n_500 == 1:
        score = 4 
    elif n_1000 >= 2:
        score = 3 
    elif n_1000 == 1:
        score = 2 
    elif n_2000 >= 1:
        score = 1 
    else:
        score = 0

    return score


def school_score(n_500, n_1000, n_2000):

    if n_500+n_1000 >= 3:
        score = 5 
    elif n_500+n_1000 == 2:
        score = 4 
    elif n_500+n_1000 == 1:
        score = 3
    elif n_2000 >= 2:
        score = 2
    elif n_2000 == 1:
        score = 1
    else:
        score = 0

    return score

# %%
def min_max_norm(x, x_max, x_min):
    return 5*(x-x_min)/(x_max-x_min)

def compute_score(user_matrix_norm, row):
    dist_s = distance_score(row['distance_to_target'])
    price_s = price_score(row['avg_price_psf'])
    lease_s = lease_score(row['remain_lease'])
    
    transport_s = surrounding_score(row['station_cnt_wth_500'], row['station_cnt_500_1km'], row['station_cnt_1km_2km'])
    mall_s = surrounding_score(row['mall_cnt_wth_500'], row['mall_cnt_500_1km'], row['mall_cnt_1km_2km'])
    hawker_s = surrounding_score(row['hawker_cnt_wth_500'], row['hawker_cnt_500_1km'], row['hawker_cnt_1km_2km'])
    school_s = school_score(row['school_cnt_wth_500'], row['school_cnt_500_1km'], row['school_cnt_1km_2km'])
    
    score = user_matrix_norm * np.array([dist_s, price_s, lease_s, transport_s, mall_s, hawker_s, school_s])
    return sum(score)

# %%
df['score'] = df.apply(lambda row: compute_score(user_matrix_norm, row), axis=1)

# %%
x_max = df['score'].max()
x_min = df['score'].min()
df['score'] = df['score'].apply(lambda x: min_max_norm(x, x_max, x_min))

# %%
df.score
# Out:
# 0     3.75
# 1     5.00
# 2     3.75
# 3     5.00
# 4     5.00
# 5     2.50
# 6     5.00
# 7     2.50
# 8     3.75
# 9     2.50
# 10    2.50
# 11    2.50
# 12    2.50
# 13    2.50
# 14    2.50
# 15    3.75
# 16    0.00
# 17    1.25
# 18    0.00
# Name: score, dtype: float64

# %% [markdown]
# ###### query nearby facility given HDB address (for detail page)

# %%
nearby_mrt_sql = """
with tmp AS
(
    SELECT 
        name,
        type,
        latitude,
        longitude,
        ST_DistanceSphere(
          ST_SetSRID(ST_Point({}, {}), 4326),
          geom
        ) as distance_to_target
    FROM api.tbl_mrt_lrt_addr_info 
    ORDER BY distance_to_target
)

SELECT *
FROM tmp
WHERE distance_to_target <= 2000
LIMIT {}
"""

nearby_hawker_sql = """
with tmp AS
(
    SELECT 
        name,
        latitude,
        longitude,
        ST_DistanceSphere(
          ST_SetSRID(ST_Point({}, {}), 4326),
          geom
        ) as distance_to_target
    FROM api.tbl_hawker_addr_info 
    ORDER BY distance_to_target
)

SELECT *
FROM tmp
WHERE distance_to_target <= 2000
LIMIT {}
"""

nearby_mall_sql = """
with tmp AS
(
    SELECT 
        name,
        latitude,
        longitude,
        ST_DistanceSphere(
          ST_SetSRID(ST_Point({}, {}), 4326),
          geom
        ) as distance_to_target
    FROM api.tbl_mall_addr_info 
    ORDER BY distance_to_target
)

SELECT *
FROM tmp
WHERE distance_to_target <= 2000
LIMIT {}
"""

nearby_school_sql = """
with tmp AS
(
    SELECT 
        school_name,
        latitude,
        longitude,
        ST_DistanceSphere(
          ST_SetSRID(ST_Point({}, {}), 4326),
          geom
        ) as distance_to_target
    FROM api.tbl_school_info 
    ORDER BY distance_to_target
)

SELECT *
FROM tmp
WHERE distance_to_target <= 2000
LIMIT {}
"""

# %%
query_lang = r['LONGITUDE']
query_lat = r['LATITUDE']
max_return = 3

# %%
query_lang
# Out:
# '103.876715676102'

# %%
query_lat
# Out:
# '1.3489086885502'

# %%
df = pd.read_sql(nearby_mall_sql.format(query_lang, query_lat, max_return), db)

# %%
df
# Out:
#                               name  latitude   longitude  distance_to_target
# 0  UPPER SERANGOON SHOPPING CENTRE  1.353481  103.878830          560.109082
# 1                              NEX  1.350675  103.871864          573.965929
# 2                        HOUGANG 1  1.353837  103.886920         1259.501334

# %%
df.to_dict(orient='records')
# Out:
# [{'address': '8 LORONG LEW LIAN SINGAPORE 531008',
#   'avg_price_psf': 507,
#   'block': '8',
#   'building': 'NIL',
#   'distance_to_target': 0.10427445,
#   'hawker_cnt_1km_2km': 4,
#   'hawker_cnt_500_1km': 0,
#   'hawker_cnt_wth_500': 0,
#   'hdb_id': 'c3146109',
#   'lease_commence_date': 1978,
#   'mall_cnt_1km_2km': 4,
#   'mall_cnt_500_1km': 1,
#   'mall_cnt_wth_500': 1,
#   'market_cnt_1km_2km': 10,
#   'market_cnt_500_1km': 5,
#   'market_cnt_wth_500': 1,
#   'remain_lease': 56,
#   'school_cnt_1km_2km': 5,
#   'school_cnt_500_1km': 3,
#   'school_cnt_wth_500': 0,
#   'station_cnt_1km_2km': 4,
#   'station_cnt_500_1km': 1,
#   'station_cnt_wth_500': 1,
#   'street_name': 'LOR LEW LIAN',
#   'town': 'SERANGOON'},
#  {'address': '7 LORONG LEW LIAN SINGAPORE 531007',
#   'avg_price_psf': 453,
#   'block': '7',
#   'building': 'NIL',
#   'distance_to_target': 42.51610081,
#   'hawker_cnt_1km_2km': 4,
#   'hawker_cnt_500_1km': 0,
#   'hawker_cnt_wth_500': 0,
# ...
