# %%
from sqlalchemy import create_engine

# %%
db_string = "postgres://hgadmin:pwd123456@127.0.0.1:5432/hdbguru"
db = create_engine(db_string)

# %%
sql = """
SELECT t1.*
FROM api.tbl_hdb_resale_price t1 LEFT JOIN api.tbl_hdb_addr_info t2 ON t1.HDB_ID = t2.HDB_ID
WHERE t2.HDB_ID IS NULL
"""

# %%
import pandas as pd

# %%
df = pd.read_sql(sql, db)

# %%
df.shape
# Out:
# (12875, 14)

# %%
15442/836330
# Out:
# 0.018464003443616754

# %%
df.groupby(['month']).size().plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
sql = """
SELECT * FROM api.TBL_HDB_ADDR_INFO
"""

df_addr = pd.read_sql(sql, db)

df_addr.columns = df_addr.columns.str.upper()

# %%
df_addr
# Out:
#                   TOWN BLOCK        STREET_NAME POSTAL_CODE  \
# 0      KALLANG/WHAMPOA     1           BEACH RD      190001
# 1                BEDOK     1    BEDOK STH AVE 1      460001
# 2         CENTRAL AREA     1      CANTONMENT RD      080001
# 3                BEDOK     1       CHAI CHEE RD      461001
# 4            PASIR RIS     1  CHANGI VILLAGE RD      500001
# ...                ...   ...                ...         ...
# 12317       QUEENSTOWN    15         HOLLAND DR      278862
# 12318       QUEENSTOWN    61        C'WEALTH DR      140061
# 12319       QUEENSTOWN    67        C'WEALTH DR      140067
# 12320       QUEENSTOWN    68        C'WEALTH DR      140068
# 12321       QUEENSTOWN    72        C'WEALTH DR      140072
#
#                                                  ADDRESS             BUILDING  \
# 0       1 BEACH ROAD BEACH ROAD GARDENS SINGAPORE 190001   BEACH ROAD GARDENS
# 1                1 BEDOK SOUTH AVENUE 1 SINGAPORE 460001                  NIL
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-55fcd94b0d56> in <module>
# ----> 1 df = pd.read_csv('data/_raw/cs5228-kaggle-dataset/test.csv')
#       2 df = pd.concat([df, pd.read_csv('data/_raw/cs5228-kaggle-dataset/train.csv')], ignore_index=True)
#       3
#       4 df.columns = df.columns.str.upper()
#       5
#
# ...
